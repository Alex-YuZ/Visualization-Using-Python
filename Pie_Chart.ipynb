# %% [markdown]
# # Pie Chart

# %% [markdown]
# **A standard pie chart**
# - start from the top of the circle
# - plot each categorical level clock-wise from most frequent to least frequent.

# %% [markdown]
# ### Example 1:
#
# Plot a simple Pie chart about counts on `generation_id` of pokemon dataset.

# %%
# Use the same pokemon dataset
pokemon = pd.read_csv('data/pokemon.csv')

sorted_counts = pokemon['generation_id'].value_counts()

plt.pie(sorted_counts, 
        labels = sorted_counts.index, 
        startangle = 90, 
        counterclock = False);

# %%
# Change the labels as `gen5`, `gen6`, `gen7` ...
labels1 = ["gen{}".format(i) for i in pokemon['generation_id'].value_counts().index]

plt.pie(sorted_counts, 
        labels = labels1, 
        startangle = 90, 
        counterclock = False);

# %%
# Make a donut plot
plt.pie(sorted_counts, \
        labels = labels1, \
        startangle = 90, \
        counterclock = False, \
        wedgeprops={'width': 0.4})

plt.text(-.5, 0, s='Pokemon', fontsize=18);

# %%
x = [5, 3, 1]

labels = ['a', 'b', 'c']

plt.pie(x, 
        startangle=90, 
        counterclock=False, 
        labels=labels, 
        autopct="%.2f%%");

# %%
x = [2, 3, 5]

labels = ['a', 'b', 'c']

plt.pie(x, startangle=90, explode=[.2, 0, 0]);

# %%
x = [2, 3, 5]

labels = ['a', 'b', 'c']

plt.pie(x, startangle=90, explode=[.1, 0, 0], labels=labels);

# %% [markdown]
# **Donut Plot**
#
# Via adjusting `wedgeprops` to draw donut chart

# %%
x = [5, 3, 1]

labels = ['a', 'b', 'c']

plt.pie(x, 
        startangle=90, 
        counterclock=False, 
        labels=labels, 
        wedgeprops={'width': 0.5});
